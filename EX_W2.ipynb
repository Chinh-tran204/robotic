# %% [markdown]
# <a href="https://colab.research.google.com/github/gamodilac/roboticHW/blob/main/EX_W2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #exercise
# #Tìm số lượng huy chương của một mục bất kì
# #tìm số huy chương vàng theo môn thi cá nhân cảu một nước
# #lọc ra các thể loại huy chương, tính mean, tính tổng,...

# %%
import pandas as pd
import numpy as np
url='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.head(21)
# Out:
#     Year      City       Sport       Discipline  NOC                Event  \
# 0   1924  Chamonix     Skating   Figure skating  AUT           individual
# 1   1924  Chamonix     Skating   Figure skating  AUT           individual
# 2   1924  Chamonix     Skating   Figure skating  AUT                pairs
# 3   1924  Chamonix   Bobsleigh        Bobsleigh  BEL             four-man
# 4   1924  Chamonix  Ice Hockey       Ice Hockey  CAN           ice hockey
# 5   1924  Chamonix    Biathlon         Biathlon  FIN      military patrol
# 6   1924  Chamonix     Skating   Figure skating  FIN                pairs
# 7   1924  Chamonix     Skating    Speed skating  FIN               10000m
# 8   1924  Chamonix     Skating    Speed skating  FIN               10000m
# 9   1924  Chamonix     Skating    Speed skating  FIN                1500m
# 10  1924  Chamonix     Skating    Speed skating  FIN                5000m
# 11  1924  Chamonix     Skating    Speed skating  FIN                5000m
# ...

# %%
#Lọc chỉ lấy huy chương vàng
url='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data = data.set_index(data['Medal'])
data.loc['Gold']
# Out:
#        Year      City       Sport      Discipline  NOC            Event  \
# Medal
# Gold   1924  Chamonix     Skating  Figure skating  AUT       individual
# Gold   1924  Chamonix     Skating  Figure skating  AUT            pairs
# Gold   1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# Gold   1924  Chamonix     Skating   Speed skating  FIN           10000m
# Gold   1924  Chamonix     Skating   Speed skating  FIN            1500m
# ...     ...       ...         ...             ...  ...              ...
# Gold   2006     Turin      Skiing   Alpine Skiing  USA  Alpine combined
# Gold   2006     Turin      Skiing   Alpine Skiing  USA     giant slalom
# Gold   2006     Turin      Skiing       Snowboard  USA        Half-pipe
# Gold   2006     Turin      Skiing       Snowboard  USA        Half-pipe
# Gold   2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#       Event gender Medal
# Medal
# Gold             W  Gold
# Gold             X  Gold
# ...

# %%
# Lọc số lượng huy chương vàng của USA
url='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data = data.set_index(data['Medal'])
data=data.loc['Gold']
data[data['NOC']=='USA'].head(10)
# Out:
#        Year                    City      Sport     Discipline  NOC  \
# Medal
# Gold   1924                Chamonix    Skating  Speed skating  USA
# Gold   1928              St. Moritz  Bobsleigh      Bobsleigh  USA
# Gold   1928              St. Moritz  Bobsleigh       Skeleton  USA
# Gold   1932             Lake Placid  Bobsleigh      Bobsleigh  USA
# Gold   1932             Lake Placid  Bobsleigh      Bobsleigh  USA
# Gold   1932             Lake Placid    Skating  Speed skating  USA
# Gold   1932             Lake Placid    Skating  Speed skating  USA
# Gold   1932             Lake Placid    Skating  Speed skating  USA
# Gold   1932             Lake Placid    Skating  Speed skating  USA
# Gold   1936  Garmisch-Partenkirchen  Bobsleigh      Bobsleigh  USA
#
#             Event Event gender Medal
# Medal
# Gold         500m            M  Gold
# Gold     five-man            M  Gold
# Gold   individual            M  Gold
# Gold     four-man            M  Gold
# ...

# %%
#Số lượng huy chương vàng của USA trong bộ môn SKiing
url='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data_USA=data[(data['Medal']=='Gold')&(data['NOC']=='USA')]
SL=data_USA['Medal'].count()
print('Số lượng huy chương vàng của USA:',SL)
data[(data['Sport']=='Skiing')&(data['Medal']=='Gold')&(data['NOC']=='USA')]
# Out:
# Số lượng huy chương vàng của USA: 78
#       Year            City   Sport      Discipline  NOC            Event  \
# 250   1948      St. Moritz  Skiing   Alpine Skiing  USA           slalom
# 316   1952            Oslo  Skiing   Alpine Skiing  USA     giant slalom
# 317   1952            Oslo  Skiing   Alpine Skiing  USA           slalom
# 784   1972         Sapporo  Skiing   Alpine Skiing  USA           slalom
# 1122  1984        Sarajevo  Skiing   Alpine Skiing  USA         downhill
# 1123  1984        Sarajevo  Skiing   Alpine Skiing  USA     giant slalom
# 1125  1984        Sarajevo  Skiing   Alpine Skiing  USA           slalom
# 1436  1992     Albertville  Skiing  Freestyle Ski.  USA           moguls
# 1614  1994     Lillehammer  Skiing   Alpine Skiing  USA         downhill
# 1617  1994     Lillehammer  Skiing   Alpine Skiing  USA          super-G
# 1819  1998          Nagano  Skiing   Alpine Skiing  USA          super-G
# ...
